# %%
install.packages('gdata')
# Out:
# also installing the dependency ‘gtools’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library('tidyLPA');
library('gdata');

# %%
dta_dir = '/home/ekaestner/Dropbox/McDonald Lab/Erik/Data/LPA'
dta_nme = 'Cognitive_data_large_sample.xlsx'

cog_dta = read.xls( paste( dta_dir , dta_nme , sep = "/" ) )

# %%
cog_dta
# Out:
#     studyID     site      Group sex    education age onset duration side
# 1   epd_ucsf001 UCSD      TLE   Female 15        33  24     9       Left
# 2   epd_ucsf002 UCSD      TLE   Male   12        43  22    21       Right
# 3   epd_ucsf003 UCSD      TLE   Male   13        24   5    19       Left
# 4   epd_ucsf004 UCSD      TLE   Female 14        47  42     5       Right
# 5   epd_ucsf005 UCSD      TLE   Female 13        55  44    11       Left
# 6   epd_ucsf006 UCSD      TLE   Female 15        20  12     8       Left
# 7   epd_ucsf007 UCSD      TLE   Male   14        24   5    19       Right
# 8   epd_ucsf008 UCSD      TLE   Male   16        33  29     4       Left
# 9   epd_ucsf009 UCSD      TLE   Male   13        24  20     4       Left
# 10  epd_ucsf010 UCSD      TLE   Male   13        29  27     2       Left
# 11  epd_ucsf011 UCSD      TLE   Male   12        25  19     6       Left
# 12  epd_ucsf012 UCSD      TLE   Male   12        24   2    22       Left
# ...
